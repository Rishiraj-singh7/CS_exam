# %% [markdown]
# import lib

# %%
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
plt.style.use('bmh')

# %%
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#    year   male  female  total
# 0  2010  16293    3827  20120
# 1  2011  18019    4157  22176
# 2  2012  21210    4893  26103
# 3  2013  25310    5807  31117
# 4  2014  31432    7846  39278

# %% [markdown]
# #Store headers/keys as variables

# %%
year = data['year']
male = data['male']
female = data['female']
yearlyTotal = data['total']

# %%
x_index = np.arange(len(year))

# %%
plt.plot(x_index, yearlyTotal)
plt.xticks(ticks=x_index, labels=year)
plt.title('Students taking AP Cs exam y year')
plt.xlabel('Year')
plt.ylabel('Number of Studetns')

plt.tight_layout()
plt.show()

# %%
# What do you notice here?
# what phenomena do you find interesting?
# why do you think this happened?
# formulate your hyponthesis based on facts.

# %%
#total Graph
plt.plot(x_index, yearlyTotal,label='Total')
#Male  Graph
plt.plot(x_index, male,label='male')
#female  Graph
plt.plot(x_index, female,label='female')

plt.legend()
plt.xticks(ticks=x_index, labels=year)
plt.title('Students taking AP Cs exam y year')
plt.xlabel('Year')
plt.ylabel('Number of Studetns')

plt.tight_layout()
plt.show()

# %%
# What do you notice here?
# what anomaly do you see?
# is this a problem?
# formulate your hypothesis based on facts?

# %% [markdown]
# create bar graph

# %%
# bar width
width = 0.2

#total Graph
plt.bar(x_index-width, yearlyTotal, width=width,label='Total')
#Male  Graph
plt.bar(x_index, male,width=width,label='male')
#female  Graph
plt.bar(x_index+width, female,width=width,label='female')

plt.legend()
plt.xticks(ticks=x_index, labels=year)
plt.title('Students taking AP Cs exam y year')
plt.xlabel('Year')
plt.ylabel('Number of Studetns')

plt.tight_layout()
plt.show()

# %%
# How can you improve the visual to better highlights the issue/trent?

# %%
#total Graph
#plt.bar(x_index-width, yearlyTotal, width=width,label='Total')
#Male  Graph
plt.barh(x_index, male,height=width,label='male')
#female  Graph
plt.barh(x_index-width, female,height=width,label='female')

plt.legend()
plt.yticks(ticks=x_index, labels=year)
plt.title('Students taking AP Cs exam y year')
plt.ylabel('Year')
plt.xlabel('Number of Studetns')

plt.tight_layout()
plt.show()
